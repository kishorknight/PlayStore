# %% [markdown]
# # EXPLORATORY DATA ANALYSIS OF GOOGLEPLAYSTORE APPS
# - Dataset which we have chosen is googleplaystore.csv
# - The data has 10841 rows and 13 columns.
# - It has 13 columns which are 'App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver'.
# - By using this data, we can get some insights on which app has the best Rating and Reviews and which app is suitable for their respective devices.
# - We can get the information on how much the app size is and what type it is.
# - We can know the different category and genres of the app by this data analysis.
# - We can get the information about which app is most installed and expensive.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/googleplaystore.csv')
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ##By using the head() function, we can display first 5 rows of the dataset

# %%
df.tail(5)
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# ##By using the tail() function, we can display last 5 rows of the dataset

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# ##shape function gives us the rows and columns of the dataset
# ##There are 10841 rows and 13 columns in the dataset

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# ##We can display the columns names of the dataset by this function

# %% [markdown]
# - App :- Name of the app
# - Category :- Classification of apps
# - Rating :- Rating of the apps [(0-5)star rating]
# - Reviews :- Total number of reviews of the apps
# - Size :- Size of the app in MegaBytes
# - Installs :- Total number of installs of the apps
# - Type :- In this dataset, we have 2 types of apps
#       - Paid app
#       - Free app
# - Price :- Price of the app in Dollars($)
# - Content Rating :- Age rating of the apps
# - Genres :- Sub classifications of the apps
# - Last Updated :- Recent update of the apps with month/date/year
# - Current Ver :- Current version code of the apps
# - Android Ver :- Required Android version to download the respective app

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# ## Out of 13 columns, there is only one numerical type data column which is the 'Rating' column.
# ## Remaining 12 are categorical type data columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ##By using the info() function, we can get the brief information about -
# - the number of rows
# - number of columns
# - type of the data columns
# - memory usage

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ##We can get the missing values in the dataset by using this function
# ## These are the missing values in each of the columns-
# - Rating - 1474
# - Type - 1
# - Content Rating -  1
# - Current Ver - 8
# - Android Ver - 3

# %%
df.isnull().sum().sum()
# Out:
# 1487

# %% [markdown]
# ## There are totally 1487 missing values in the given dataset.

# %% [markdown]
# #➡Analysis of Categorys of apps :
#
# ---
#
#
#
#
# ---

# %%
df.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %% [markdown]
# ## By using the unique() function, we can display unique values in a particular column of the dataset
# ## These are the unique category of the apps in the given dataset.

# %%
df.Category.value_counts()
print(len(df.Category.unique()))
# Out:
# 34

# %% [markdown]
# ## There are totally 34 unique categories of the apps in the dataset.

# %%
sns.barplot(df.Category.value_counts().head().keys(), df.Category.value_counts().head())
plt.xlabel('Category')
plt.ylabel('counts')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## - By using the barplot, we have visualized the 'Category' column of the dataset
# ## - These are the Top 5 Category of apps preferred in the playstore

# %% [markdown]
# #➡Analysis of ratings of apps :
#
#
# ---
#
#
#
# ---

# %%
df.Rating.value_counts().tail()
# Out:
# 1.6     4
# 1.4     3
# 1.5     3
# 1.2     1
# 19.0    1
# Name: Rating, dtype: int64

# %% [markdown]
# ## These are the least 5 ratings of the apps in the playstore
# ## There is an outlier in the 'Rating' column

# %%
df.loc[df.Rating==19.0] #searching for the row which has the outlier
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# ## There is an outlier present in 'Rating' column of the app named 'Life Made WI-Fi Touchscreen Photo Frame' in the row '10472'.

# %%
df.Rating.describe()
# Out:
# count    9367.000000
# mean        4.193338
# std         0.537431
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max        19.000000
# Name: Rating, dtype: float64

# %% [markdown]
# ## By the describe() fucntion, we can get the statistical information of the columns in the dataset.
# ## Statistical information of the 'Rating' column -
#  - Average rating of the apps is 4.19
#  - Minimum rating of an app is 1
#  - Maximum rating of an app is 5
#  - Count of the ratings of the apps is 9367

# %% [markdown]
# # Removing outliers and replacing it by suitable data

# %%
df['Category']=df['Category'].replace('1.9','TOOLS')
df['Rating']=df['Rating'].replace(19.000000,5.0)

# %% [markdown]
# ### We can observe that the outlier is replaced with replace fucntion

# %%
df.groupby('Category')['Rating'].mean().sort_values(ascending=False).head(3)
# Out:
# Category
# EVENTS            4.435556
# EDUCATION         4.389032
# ART_AND_DESIGN    4.358065
# Name: Rating, dtype: float64

# %% [markdown]
# ## By using the groupby function, we can group the data in a particular column of the dataset
# ## Taking the mean of ratings of the Top 3 categories in the 'Category column'.

# %%
cat_gk=df.groupby('Category')
cat_gk.first()

# %% [markdown]
# ## Creating a group for the 'Category' column in the given dataset

# %%
sns.barplot(cat_gk['Rating'].mean().sort_values(ascending=False).head(),cat_gk['Rating'].mean().sort_values(ascending=False).head().keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## We have visualized the Top 5 categories of apps which has the maximum average rating in the playstore.
# ## 'EVENTS' category apps has the maximum average rating in the playstore.

# %%
sns.barplot(cat_gk['Rating'].mean().sort_values(ascending=True).head(),cat_gk['Rating'].mean().sort_values(ascending=True).head().keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## We have visualized the least 5 categories of apps which has the minimum average rating in playstore.
# ## 'DATING' category apps has the minimum average rating in the playstore.

# %%
df_5_star=df[df['Rating']==5.0] #creating a seperate dataframe of 5 star rated apps
print(df_5_star.head(3))
five_star_apps=len(df_5_star)
print('length=',five_star_apps)

# %% [markdown]
# ## Out of 10841 apps, there are totally 274 apps rated 5 star in the playstore.

# %%
sns.barplot(df_5_star.Category.value_counts().head().keys(),df_5_star.Category.value_counts().head())
plt.xlabel('Category')
plt.ylabel('counts')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##We have visualized the 'Category' column of the apps using Barplot.
# ## These are the top five categories which has the most 5 star rated apps in the playstore.

# %%
per=(five_star_apps/len(df.Rating))*100
print('percentage of 5 star apps = %.2f'%per)
# Out:
# percentage of 5 star apps = 2.54

# %% [markdown]
# ## The total percentage of 5 star rated apps in the playstore is 2.54

# %%
rat=df.Rating.value_counts()
rat_per=rat/len(df.Rating)*100
print('percentage of variable ratings in playstore')
print(rat_per)
# Out:
# percentage of variable ratings in playstore
# 4.4    10.229684
# 4.3     9.925284
# 4.5     9.574762
# 4.2     8.781478
# 4.6     7.591551
# 4.1     6.530763
# 4.0     5.239369
# 4.7     4.602896
# 3.9     3.560557
# 3.8     2.794945
# 5.0     2.536666
# 3.7     2.204594
# 4.8     2.158472
# 3.6     1.605018
# 3.5     1.503551
# 3.4     1.180703
# 3.3     0.940873
# 4.9     0.802509
# 3.0     0.765612
# 3.1     0.636473
# 3.2     0.590351
# 2.9     0.415091
# 2.8     0.387418
# 2.7     0.230606
# 2.6     0.230606
# 2.5     0.193709
# 2.3     0.184485
# 2.4     0.175261
# 1.0     0.147588
# 2.2     0.129139
# 1.9     0.119915
# 2.0     0.110691
# 1.7     0.073794
# 1.8     0.073794
# 2.1     0.073794
# 1.6     0.036897
# 1.4     0.027673
# 1.5     0.027673
# 1.2     0.009224
# Name: Rating, dtype: float64

# %% [markdown]
# ## These are the percentages of all the ratings of the apps in the playstore.
# # Maximum number of apps in the playstore have a rating of 4.4
# #  Minimum number of apps in the playstore have a rating of 1.2

# %%
df_1_star=df[df['Rating']==1.0] #creating a seperate dataframe of 1 star rated apps
min_rated_apps=df_1_star.App.values
print('********totally %d Apps are rated as 1 star in playstore********'%len(df_1_star))
print('------>This are the 1 star rated apps')
for i in min_rated_apps:
  print(i)
# Out:
# ********totally 16 Apps are rated as 1 star in playstore********
# ------>This are the 1 star rated apps
# House party - live chat
# Speech Therapy: F
# Clarksburg AH
# Truck Driving Test Class 3 BC
# BJ Bridge Standard American 2018
# MbH BM
# CB Mobile Biz
# Thistletown CI
# CJ DVD Rentals
# CR Magazine
# Tech CU Card Manager
# DS Creator 2.0
# DT future1 cam
# FE Mechanical Engineering Prep
# Familial Hypercholesterolaemia Handbook
# Lottery Ticket Checker - Florida Results & Lotto

# %% [markdown]
# ## 0ut of 10841 apps, 16 apps are rated 1 star in playstore
# ## The 16 apps are displayed above
# ### The total percentage of 1 star rated apps is 0.1475

# %% [markdown]
# #➡Analysis of Reviews of apps :
#
# ---
#
#
#
# ---

# %%
df.Reviews.dtypes
# Out:
# dtype('O')

# %%
df.Reviews.astype('float')#converting datatype of review column from object to float
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-fc9ce9db8249> in <module>
# ----> 1 df.Reviews.astype('float')#converting datatype of review column from object to float
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
# ...

# %%
#an outlier present in column reviews

# %%
df[df['Reviews']=='3.0M']#searching for outlier row
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame    TOOLS     5.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
#outlier present in 10472 row

# %%
df['Reviews']=df['Reviews'].replace('3.0M',3000000)#replacing outlier of reviews with suitable data
df.Reviews=df.Reviews.astype('float')#converting datatype of review column from object to float
df.Reviews.dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ## Reviews are converted object to float type

# %%
df.Reviews.describe()
# Out:
# count    1.084100e+04
# mean     4.443887e+05
# std      2.927728e+06
# min      0.000000e+00
# 25%      3.800000e+01
# 50%      2.094000e+03
# 75%      5.479800e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %% [markdown]
# ## The datatype of 'Reviews' data column is object.

# %%
df.Reviews.describe()
# Out:
# count    1.084100e+04
# mean     4.443887e+05
# std      2.927728e+06
# min      0.000000e+00
# 25%      3.800000e+01
# 50%      2.094000e+03
# 75%      5.479800e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %% [markdown]
# ## Statistical data of the 'Reviews' column -
#  - Average reviews of the apps is 4.443887e+05
#  - Minimum review of an app is 0.0
#  - Maximum review of an is 7.815831e+07
#  - Count of the reviews of the apps is 1.084100e+04

# %%
cat_rev=df.groupby('Category')
sns.barplot(cat_rev['Reviews'].mean().sort_values(ascending=False).head().keys(),cat_rev['Reviews'].mean().sort_values(ascending=False).head())
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## These are the top 5 category of apps having the maximum average of reviews
# ### In above bargraph visualisation, 1 unit equals 10 million reviews.
# ## 'COMMUNICATION' category apps have the most reviews.

# %%
df.rename(columns={'Content Rating':'Content_Rating'},inplace=True)
df.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#    Reviews Size Installs  Type Price Content_Rating        Genres  \
# 0    159.0  19M  10,000+  Free     0       Everyone  Art & Design
#
#       Last Updated Current Ver   Android Ver
# 0  January 7, 2018       1.0.0  4.0.3 and up

# %% [markdown]
# ## We can observe that 'Content Rating' column is renamed into Content_Rating using rename function.

# %%
df.rename(columns={'Android Ver':'Android_Ver','Current Ver':'Current_Ver','Last Updated':'Last_Updated'},inplace=True)
df.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#    Reviews Size Installs  Type Price Content_Rating        Genres  \
# 0    159.0  19M  10,000+  Free     0       Everyone  Art & Design
#
#       Last_Updated Current_Ver   Android_Ver
# 0  January 7, 2018       1.0.0  4.0.3 and up

# %% [markdown]
# ## We renamed 'Android Ver' column into Android_Ver using rename function.

# %%
df_games=df[df['Category']=='GAME']  # creating seperate dataframe for game category
df_COMMUNICATION=df[df['Category']=='COMMUNICATION']  # creating seperate dataframe for communication category
df_SOCIAL=df[df['Category']=='SOCIAL']  # creating seperate dataframe for social category
df_PHOTOGRAPHY=df[df['Category']=='PHOTOGRAPHY']  # creating seperate dataframe for photography category
df_VIDEO_PLAYERS=df[df['Category']=='VIDEO_PLAYERS']  # creating seperate dataframe for videoplayers category
game_rev=df_games.groupby('App')  # creating a group of game dataframe with keeping key as app
COMMUNICATION_rev=df_COMMUNICATION.groupby('App')  # creating a group of communication dataframe with keeping key as app
SOCIAL_rev=df_SOCIAL.groupby('App')  # creating a group of social dataframe with keeping key as app
PHOTOGRAPHY_rev=df_PHOTOGRAPHY.groupby('App')  # creating a group of photography dataframe with keeping key as app
VIDEO_PLAYERS_rev=df_VIDEO_PLAYERS.groupby('App')  # creating a group of videoplayer dataframe with keeping key as app

# %%
sns.barplot(game_rev['Reviews'].mean().sort_values(ascending=False).head(),game_rev['Reviews'].mean().sort_values(ascending=False).head().keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## These are the top 5 reviewed games in playstore.
# ## Clash of Clans is the most reviewed game in the playstore.
# ###In above bargraph visualisation, 1 unit equals 10 million reviews.

# %%
sns.barplot(COMMUNICATION_rev['Reviews'].mean().sort_values(ascending=False).head(),COMMUNICATION_rev['Reviews'].mean().sort_values(ascending=False).head().keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## These are the top 5 reviewed COMMUNICATION apps in the playstore
# ## WhatsApp Messenger is the most reviewed communication app in the playstore
# ###In above bargraph visualisation, 1 unit  equals 10 million reviews

# %%
sns.barplot(SOCIAL_rev['Reviews'].mean().sort_values(ascending=False).head(),SOCIAL_rev['Reviews'].mean().sort_values(ascending=False).head().keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## These are the top 5 reviewed SOCIAL MEDIA apps in the playstore
# ## Facebook is the most reviewed SOCIAL MEDIA app in the playstore
# ### In above bargraph visualisation, 1 unit equals 10 million reviews

# %%
sns.barplot(PHOTOGRAPHY_rev['Reviews'].mean().sort_values(ascending=False).head(),PHOTOGRAPHY_rev['Reviews'].mean().sort_values(ascending=False).head().keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## These are the top 5 reviewed PHOTOGRAPHY apps in the playstore
# ## Google Photos is the most reviewed PHOTOGRAPHY app in the playstore
# ### In above bargraph visualisation, 1 unit equals 10 million reviews

# %%
sns.barplot(VIDEO_PLAYERS_rev['Reviews'].mean().sort_values(ascending=False).head(),VIDEO_PLAYERS_rev['Reviews'].mean().sort_values(ascending=False).head().keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## These are the top 5 VIDEO PLAYER apps in playstore with most reviews
# ## YouTube is the most reviewed VIDEO PLAYER app in the playstore
# ###In above bargraph visualisation, 1 unit equals 10 million reviews

# %%
sns.barplot(df.groupby('App')['Reviews'].mean().sort_values(ascending=False).head(5),df.groupby('App')['Reviews'].mean().sort_values(ascending=False).head(5).keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## these are the top 5 reviewed apps in the playstore
# ## Facebook is the most reviewed app in the playstore
# ###In above bargraph visualisation, 1 unit equals 10 million reviews

# %% [markdown]
# #➡Analysis of Installs :
#
# ---
#
#
#
# ---

# %%
df.Installs.dtype
# Out:
# dtype('O')

# %% [markdown]
# ## The datatype of 'Installs' data column is object.

# %%
df['Installs']=df['Installs'].str.replace(',','')#removing " , " from installs data
df['Installs']=df['Installs'].str.replace('+','')#removing " + " from installs data
df['Installs']=df['Installs'].str.replace('Free','0')#replacing free to 0 in installs data

df.Installs
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 10841, dtype: object

# %%
df.Installs=df.Installs.astype('int')

# %%
df.Installs.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ##installs is converted from object to int data

# %%
df.Installs.describe()
# Out:
# count    1.084100e+04
# mean     1.546291e+07
# std      8.502557e+07
# min      0.000000e+00
# 25%      1.000000e+03
# 50%      1.000000e+05
# 75%      5.000000e+06
# max      1.000000e+09
# Name: Installs, dtype: float64

# %% [markdown]
# ## Statistical data of 'Installs' column
# - Average installs of the apps   :  1.546291e+07
# - Minimum installs of an app    : 0.0
# - Maximum installs of an app    : 1.000000e+09

# %%
index=df.Installs.sort_values(ascending=False).head(10).keys()#abstracting index number(row number)of  top 10 most installed apps
index
print(df.iloc[index]['App'].unique())
# Out:
# ['Subway Surfers' 'Facebook' 'Messenger – Text and Video Chat for Free'
#  'Google Drive' 'Google Photos' 'YouTube' 'Skype - free IM & video calls'
#  'Google Play Movies & TV']

# %% [markdown]
# ##this are the top 10 Installed apps in playstore

# %%
sns.barplot(cat_gk['Installs'].mean().sort_values(ascending=False).head(5),cat_gk['Installs'].mean().sort_values(ascending=False).head(5).keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## These are the top 5 category of apps having maximum average of installs
# ## 'COMMUNICATION' category apps has the maximum average of installs
# ### In above bargraph visualisation, 1 unit equals 10 million installs

# %%
df_games=df[df['Category']=='GAME']  # creating seperate dataframe for game category
df_COMMUNICATION=df[df['Category']=='COMMUNICATION']  # creating seperate dataframe for communication category
df_SOCIAL=df[df['Category']=='SOCIAL']  # creating seperate dataframe for social category
df_PHOTOGRAPHY=df[df['Category']=='PHOTOGRAPHY']  # creating seperate dataframe for photography category
df_VIDEO_PLAYERS=df[df['Category']=='VIDEO_PLAYERS']  # creating seperate dataframe for videoplayers category
game_rev=df_games.groupby('App')  # creating a group of game dataframe with keeping key as app
COMMUNICATION_rev=df_COMMUNICATION.groupby('App')  # creating a group of communication dataframe with keeping key as app
SOCIAL_rev=df_SOCIAL.groupby('App')  # creating a group of social dataframe with keeping key as app
PHOTOGRAPHY_rev=df_PHOTOGRAPHY.groupby('App')  # creating a group of photography dataframe with keeping key as app
VIDEO_PLAYERS_rev=df_VIDEO_PLAYERS.groupby('App')  # creating a group of videoplayer dataframe with keeping key as app

# %%
sns.barplot(game_rev['Installs'].mean().sort_values(ascending=False).head(),game_rev['Installs'].mean().sort_values(ascending=False).head().keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##These are the top 5 most installed games in the playstore
# ## Subway Surfers is the most installed game in the playstore
# ### In above bargraph visualisation, 1 unit equals 1 billion installs

# %%
sns.barplot(COMMUNICATION_rev['Installs'].mean().sort_values(ascending=False).head(),COMMUNICATION_rev['Installs'].mean().sort_values(ascending=False).head().keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## These are the top 5 most installed communication apps in the playstore
# ## Hangouts is the most installed communication app in the playstore
# ###In above bargraph visualisation, 1 unit equals 1 billion installs

# %%
sns.barplot(SOCIAL_rev['Installs'].mean().sort_values(ascending=False).head(),SOCIAL_rev['Installs'].mean().sort_values(ascending=False).head().keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##These are the top 5 most installed social media apps in playstore
# ## Google+ is the most installed social media app in the playstore
# ### In above bargraph visualisation, 1 unit equals 1 billion installs

# %%
sns.barplot(VIDEO_PLAYERS_rev['Installs'].mean().sort_values(ascending=False).head(),VIDEO_PLAYERS_rev['Installs'].mean().sort_values(ascending=False).head().keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## These are the top 5 most installed video player apps in playstore
# ## Google play Movies & TV is the most installed video player app in playstore
# ### In above bargraph visualisation, 1 unit equals 1 billion installs

# %%
df_PRODUCTIVITY=df[df['Category']=='PRODUCTIVITY']
PRODUCTIVITY_rev=df_PRODUCTIVITY.groupby('App')
sns.barplot(PRODUCTIVITY_rev['Installs'].mean().sort_values(ascending=False).head(),PRODUCTIVITY_rev['Installs'].mean().sort_values(ascending=False).head().keys(),orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## These are the top 5 most installed productivity apps in playstore
# ## Google Drive is the most installed productivity app in playstore
# ### In above bargraph visualisation, 1 unit equals 1 billion installs

# %% [markdown]
# #➡Analysis of types and price of apps :
#
# ---
#
#
#
# ---

# %%
df.Type.value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %% [markdown]
# ##Out of 10841 apps, there are totally 10039 free apps and 800 paid apps

# %%
df.groupby('Type')['Rating'].mean()
# Out:
# Type
# 0       5.000000
# Free    4.186203
# Paid    4.266615
# Name: Rating, dtype: float64

# %% [markdown]
# ## the average rating of the free apps is 4.1
# ## the average rating of the paid apps is 4.2

# %%
print(df.Price.unique())
print(df.Price.dtype)
df['Price']=df['Price'].str.replace('$','')
df['Price']=df['Price'].str.replace('Everyone','0')
print(df.Price.unique())
df['Price']=df['Price'].astype('float')
print(df.Price.dtype)

# %% [markdown]
# ##outliers are removed and price is converted from object to float

# %%
df.Price.describe()
# Out:
# count    10841.000000
# mean         1.027273
# std         15.948971
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        400.000000
# Name: Price, dtype: float64

# %% [markdown]
# ## the statistical data of Price -
# - Mean price of apps in playstore : 1.027273
# - Min price of apps in playstore : 0.000000
# - Max price of apps in playstore : 400.000000
# ### Above prices are in Dollars

# %%
df[df['Price']==df.Price.max()]
# Out:
#                            App   Category  Rating  Reviews  Size  Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6    275.0  7.3M     10000
#
#       Type  Price Content_Rating     Genres Last_Updated Current_Ver  \
# 4367  Paid  400.0       Everyone  Lifestyle  May 3, 2018       1.0.1
#
#      Android_Ver
# 4367  4.1 and up

# %% [markdown]
# ##'I'm Rich - Trump Edition' is the most expensive app in the playstore which costs 400$

# %%
plt.hist(df.Price,bins=10)
plt.title('price of apps in playstore')
plt.xlabel('price in $')
plt.ylabel('app counts')
plt.show()

# %% [markdown]
# ## We can observe by the histogram that most of the apps in the playstore are priced between 0 to 40 Dollars($)

# %% [markdown]
# #➡Analysis of size of apps :
#
#
#
#
# ---
#
#
#
# ---

# %%
df.Size.unique()

# %%
df.Size.value_counts()
# Out:
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 429k                     1
# 200k                     1
# 460k                     1
# 728k                     1
# 619k                     1
# Name: Size, Length: 462, dtype: int64

# %% [markdown]
# ##In most of the apps size varies with devices

# %% [markdown]
# #➡Analysis of content rating :
#
# ---
#
#
#
# ---

# %%
print(df.Content_Rating.unique())
# Out:
# ['Everyone' 'Teen' 'Everyone 10+' 'Mature 17+' 'Adults only 18+' 'Unrated'
#  nan]

# %% [markdown]
# ##there are totally 6 unique ratings of apps in given dataset

# %%
#analysing data of content rating

sns.countplot(df.Content_Rating)
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##A barplot is plotted for Content_rating
# ### We can observe that maximum number of apps are rated for everyone

# %%
sns.countplot(df_games.Content_Rating)
plt.title('content rating for games',fontsize=18, style="italic", fontweight="bold")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## We can observe that most of the games are rated for everyone

# %%
sns.countplot(df_COMMUNICATION.Content_Rating)
plt.title('content rating for communication apps',fontsize=18, style="italic", fontweight="bold")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## We can observe that most of the communication apps are rated for everyone

# %%
sns.countplot(df_SOCIAL.Content_Rating)
plt.title('content rating for social media',fontsize=18, style="italic", fontweight="bold")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## We can observe that most of the social media are rated for Teens

# %%
sns.countplot(df_PHOTOGRAPHY.Content_Rating)
plt.title('content rating for photography apps',fontsize=18, style="italic", fontweight="bold")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## We can observe that most of the photography apps are rated for everyone

# %%
sns.countplot(df_VIDEO_PLAYERS.Content_Rating)
plt.title('content rating for video player apps',fontsize=18, style="italic", fontweight="bold")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##We can observe that most of the video player apps are rated for everyone

# %%
sns.countplot(df_PRODUCTIVITY.Content_Rating)
plt.title('content rating for productivity apps',fontsize=18, style="italic", fontweight="bold")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##We can observe that most of the productivity apps are rated for everyone

# %% [markdown]
# #➡Analysis of Genres :
#
# ---
#
#
#
# ---

# %%
df.Genres.value_counts()
# Out:
# Tools                     842
# Entertainment             623
# Education                 549
# Medical                   463
# Business                  460
#                          ...
# Arcade;Pretend Play         1
# Card;Brain Games            1
# Lifestyle;Pretend Play      1
# Comics;Creativity           1
# Strategy;Creativity         1
# Name: Genres, Length: 120, dtype: int64

# %% [markdown]
# ## Out of 120 different Genres of apps, 'Tools' Genre has the most apps in the playstore which is 842.

# %%
sns.barplot(df.Genres.value_counts().head().keys(),df.Genres.value_counts().head())
plt.xlabel('Geners')
plt.ylabel('count')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## These are the Top 5 genres of apps in playstore
# ## Most of the apps are under 'Tools' Genre

# %% [markdown]
# #➡Analysis of Android_Version :
#
# ---
#
#
#
# ---

# %%
df.Android_Ver.value_counts().head(10)
# Out:
# 4.1 and up            2451
# 4.0.3 and up          1501
# 4.0 and up            1375
# Varies with device    1362
# 4.4 and up             980
# 2.3 and up             652
# 5.0 and up             601
# 4.2 and up             394
# 2.3.3 and up           281
# 2.2 and up             244
# Name: Android_Ver, dtype: int64

# %% [markdown]
# ## These are top 10 Android versions which are required to use the apps
# ## Required Android version for most of the apps in given dataset is 4.1 and up

# %%
plt.figure(figsize=(14,10))
plt.pie(df.Android_Ver.value_counts().head(10),labels=df.Android_Ver.value_counts().head(10).keys(),shadow=True,explode=[0.2,0.2,0.1,0.1,0,0,0,0,0,0])
plt.legend(title="Android version")
plt.show()

# %% [markdown]
# ##We can observe by the pie chart that the required Android version for most of the apps in given dataset should be 4.1 and up

# %% [markdown]
# #➡Analysis of Current_Version of app :
#
# ---
#
#
#
# ---

# %%
df.Current_Ver.value_counts().head(10)
# Out:
# Varies with device    1459
# 1.0                    809
# 1.1                    264
# 1.2                    178
# 2.0                    151
# 1.3                    145
# 1.0.0                  136
# 1.0.1                  119
# 1.4                     88
# 1.5                     81
# Name: Current_Ver, dtype: int64

# %% [markdown]
# ##These are the top 10 app versions of the apps in playstore
# ## The app version for most of the apps varies with device

# %%
plt.figure(figsize=(14,10))
plt.pie(df.Current_Ver.value_counts().head(10),labels=df.Current_Ver.value_counts().head(10).keys(),shadow=True,explode=[0.2,0.2,0,0,0,0,0,0,0,0])
plt.legend(title="current app version")
plt.show()

# %% [markdown]
# ## We can observe by the pie chart that most of the app versions varies with devices
